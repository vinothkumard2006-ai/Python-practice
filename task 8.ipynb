# %% [markdown]
# # Import libraries and Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("student_exam_scores.csv")

# %%
data
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
data.shape
# Out:
# (200, 6)

# %%
data.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
data.head(5)
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001            8.0          8.8                72.1               45
# 1       S002            1.3          8.6                60.7               55
# 2       S003            4.0          8.2                73.7               86
# 3       S004            3.5          4.8                95.1               66
# 4       S005            9.1          6.4                89.8               71
#
#    exam_score
# 0        30.2
# 1        25.0
# 2        35.8
# 3        34.0
# 4        40.3

# %%
data.tail(5)
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 195               87        42.7
# 196               92        40.4
# 197               76        28.2
# 198               58        42.0
# 199               68        37.8

# %%
data.size
# Out:
# 1200

# %%
data.columns
# Out:
# Index(['student_id', 'hours_studied', 'sleep_hours', 'attendance_percent',
#        'previous_scores', 'exam_score'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          200 non-null    object
#  1   hours_studied       200 non-null    float64
#  2   sleep_hours         200 non-null    float64
#  3   attendance_percent  200 non-null    float64
#  4   previous_scores     200 non-null    int64
#  5   exam_score          200 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 9.5+ KB

# %% [markdown]
# # Data cleaning

# %%
data.isna().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.nunique()
# Out:
# student_id            200
# hours_studied          96
# sleep_hours            50
# attendance_percent    167
# previous_scores        54
# exam_score            139
# dtype: int64

# %%
data.dtypes
# Out:
# student_id             object
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %%
data["student_id"]=data["student_id"].str.replace(r"\D","",regex=True).astype(int)

# %%
data.dtypes
# Out:
# student_id              int64
# hours_studied         float64
# sleep_hours           float64
# attendance_percent    float64
# previous_scores         int64
# exam_score            float64
# dtype: object

# %% [markdown]
# # Data Exploration

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   student_id          200 non-null    int64
#  1   hours_studied       200 non-null    float64
#  2   sleep_hours         200 non-null    float64
#  3   attendance_percent  200 non-null    float64
#  4   previous_scores     200 non-null    int64
#  5   exam_score          200 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 9.5 KB

# %%
data.shape
# Out:
# (200, 6)

# %%
data.describe()
# Out:
#        student_id  hours_studied  sleep_hours  attendance_percent  \
# count  200.000000     200.000000   200.000000          200.000000
# mean   100.500000       6.325500     6.622000           74.830000
# std     57.879185       3.227317     1.497138           14.249905
# min      1.000000       1.000000     4.000000           50.300000
# 25%     50.750000       3.500000     5.300000           62.200000
# 50%    100.500000       6.150000     6.700000           75.250000
# 75%    150.250000       9.000000     8.025000           87.425000
# max    200.000000      12.000000     9.000000          100.000000
#
#        previous_scores  exam_score
# count       200.000000  200.000000
# mean         66.800000   33.955000
# std          15.663869    6.789548
# min          40.000000   17.100000
# 25%          54.000000   29.500000
# 50%          67.500000   34.050000
# 75%          80.000000   38.750000
# max          95.000000   51.300000

# %%
data.value_counts()
# Out:
# student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  exam_score
# 1           8.0            8.8          72.1                45               30.2          1
# 2           1.3            8.6          60.7                55               25.0          1
# 3           4.0            8.2          73.7                86               35.8          1
# 4           3.5            4.8          95.1                66               34.0          1
# 5           9.1            6.4          89.8                71               40.3          1
#                                                                                           ..
# 196         10.5           5.4          94.0                87               42.7          1
# 197         7.1            6.1          85.1                92               40.4          1
# 198         1.6            6.9          63.8                76               28.2          1
# ...

# %%
print(data["exam_score"].describe())
print("Range:",data["exam_score"].max()-data["exam_score"].min())
print("Skewness:",data["exam_score"].skew())
# Out:
# count    200.000000
# mean      33.955000
# std        6.789548
# min       17.100000
# 25%       29.500000
# 50%       34.050000
# 75%       38.750000
# max       51.300000
# Name: exam_score, dtype: float64
# Range: 34.199999999999996
# Skewness: 0.03257466628892812

# %% [markdown]
# # Data Visualization

# %%
sns.histplot(data["exam_score"],kde=True)
# Out:
# <Axes: xlabel='exam_score', ylabel='Count'>

# %%
sns.countplot(x="exam_score",data=data)
# Out:
# <Axes: xlabel='exam_score', ylabel='count'>

# %%
sns.scatterplot(x="previous_scores",y="exam_score",data=data)
# Out:
# <Axes: xlabel='previous_scores', ylabel='exam_score'>

# %%
sns.boxplot(x="previous_scores",y="exam_score",data=data)
# Out:
# <Axes: xlabel='previous_scores', ylabel='exam_score'>

# %%
sns.pairplot(data[["previous_scores","exam_score","hours_studied"]])

# %%
data.groupby(["previous_scores","exam_score"])["hours_studied"].mean()
# Out:
# previous_scores  exam_score
# 40               20.8           3.3
#                  28.6           6.6
#                  29.7           2.3
# 41               34.1           7.0
# 42               26.3           5.4
#                                ...
# 95               28.8           1.6
#                  36.0           6.8
#                  39.8           7.4
#                  42.0           8.4
#                  51.3          12.0
# Name: hours_studied, Length: 199, dtype: float64
