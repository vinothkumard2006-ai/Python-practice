# %% [markdown]
# # Question 1

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age

student1=Student("Vinoth",19)
print("name:",student1.name)
print("age:",student1.age)
# Out:
# name: Vinoth
# age: 19

# %% [markdown]
# # Question 2

# %%
import math
class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius**2
c1=Circle(10)
print("Area:",c1.area())
# Out:
# Area: 314.1592653589793

# %% [markdown]
# # Question 3

# %%
numbers=int(input("Enter an integer:"))
text=input("Enter a string:")
print("Integer:",numbers)
print("String:",text)
# Out:
# Enter an integer: 19
# Enter a string: vinothkumar
# Integer: 19
# String: vinothkumar

# %% [markdown]
# # Question 4

# %% [markdown]
# ## Mean

# %% [markdown]
# #### Mean is the average value of the dataset(sum of values/number of values)

# %% [markdown]
# ## Mode

# %% [markdown]
# ### Mode is the most frequency occuring value in the dataset

# %% [markdown]
# ## Median

# %% [markdown]
# ### Median is the middle value when the data is arranged in order

# %% [markdown]
# ## Population

# %% [markdown]
# ### the entire group of individuals or items under study

# %% [markdown]
# ## Sample

# %% [markdown]
# ### A subset of the population used for analysis

# %% [markdown]
# # Question 5

# %%
class Vehicle:
    def start(self):
        print("Vehicle has started")
class Car(Vehicle):  
    def start(self):
        print("Car has started")
c=Car()
c.start()
# Out:
# Car has started

# %% [markdown]
# # Question 6

# %%
class Employee:
    def __init__(self,name,position,salary):
        self.name=name
        self.position=position
        self.salary=salary

    def display(self):
        print(f"name:{self.name},position:{self.position},salary:{self.salary}")

employee1=Employee("Alice","Manager",60000)
employee2=Employee("vinoth","salesman",20000)

employee1.display()
employee2.display()
# Out:
# name:Alice,position:Manager,salary:60000
# name:vinoth,position:salesman,salary:20000

# %% [markdown]
# # Question 7

# %%
import statistics

data=[12,15,20,22,18,30,25]
std_dev=statistics.stdev(data)
print("Standard Deviation:",std_dev)
# Out:
# Standard Deviation: 6.074928962939559

# %% [markdown]
# # Question 8

# %%
class BankAccount():
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance")

    def get_balance(self):
        return self.__balance

account = BankAccount()
account.deposit(500)
account.withdraw(300)
print("Balance:", account.get_balance())
# Out:
# Balance: 200

# %% [markdown]
# # Question 9

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}")

class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def display(self):
        super().display()
        print("Subject:", self.subject)

class Student(Person):
    def __init__(self, name, age, course):
        super().__init__(name, age)
        self.course = course

    def display(self):
        super().display()
        print("Course:", self.course)

teacher = Teacher("Ravi", 40, "Math")
student = Student("Kumar", 20, "Data Science")

teacher.display()
student.display()
# Out:
# Name: Ravi, Age: 40
# Subject: Math
# Name: Kumar, Age: 20
# Course: Data Science

# %% [markdown]
# # Question 10

# %%
import random

def simulate_red_probability(trials=1000):
    red_count = 0
    for _ in range(trials):
        ball = random.choice(["red"]*4 + ["blue"]*6)
        if ball == "red":
            red_count += 1
    return red_count / trials

print("Estimated Probability of Red:", simulate_red_probability())
# Out:
# Estimated Probability of Red: 0.385
